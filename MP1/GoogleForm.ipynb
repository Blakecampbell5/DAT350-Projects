# %% [markdown]
# The purpose of this notebook is to analyze the data I retrived in my google form.

# %%
import pandas as pd

# %%
dataDF = pd.read_csv("Favorite Sport to Watch.csv")
editeddataDF = dataDF.drop("Timestamp", axis = 1)
editeddataDF
# Out:
#    What is your age?  \
# 0              20-25
# 1              10-19
# 2              10-19
# 3              10-19
# 4                40+
# 5              20-25
# 6              20-25
# 7              20-25
# 8                40+
# 9                40+
# 10             10-19
# 11             20-25
# 12               40+
# 13             20-25
# 14             10-19
# 15             26-30
# 16             20-25
# 17             20-25
# 18             10-19
# 19             20-25
# 20             20-25
# 21             20-25
# 22               40+
# 23             20-25
# 24             10-19
# 25             10-19
# 26             20-25
#
#    What is your level of education? (or currently pursuing)?  \
# 0                                     Bachelor Degree
# 1                                  High School or GED
# 2                                     Bachelor Degree
# 3                                     Bachelor Degree
# 4                                Masters or Doctorate
# ...

# %%
dataDF.shape
# Out:
# (27, 11)

# %%
ageDF = editeddataDF["What is your age?"].value_counts()

agePercent = ageDF / len(editeddataDF)
agePercent *100
# Out:
# What is your age?
# 20-25    48.148148
# 10-19    29.629630
# 40+      18.518519
# 26-30     3.703704
# Name: count, dtype: float64

# %%
educationDF = editeddataDF["What is your level of education? (or currently pursuing)?"].value_counts()

edPercent = educationDF / len(editeddataDF)
edPercent *100
# Out:
# What is your level of education? (or currently pursuing)?
# Bachelor Degree         55.555556
# Masters or Doctorate    22.222222
# High School or GED      14.814815
# Associate Degree         7.407407
# Name: count, dtype: float64

# %%
ethnicityDF = editeddataDF["What is your Ethnicity?"].value_counts()

ethPercent = ethnicityDF / len(editeddataDF)
ethPercent *100
# Out:
# What is your Ethnicity?
# White               85.185185
# African American    11.111111
# Australian           3.703704
# Name: count, dtype: float64

# %%
favDF = editeddataDF["What is your favorite sport to watch?"].value_counts()

favPercent = favDF / len(editeddataDF)
favPercent *100
# Out:
# What is your favorite sport to watch?
# Basketball                    62.962963
# Football                      25.925926
# Fencing                        3.703704
# Underwater golf basketball     3.703704
# Baseball                       3.703704
# Name: count, dtype: float64

# %% [markdown]
# I am not sure why this error is occuring only for this column.

# %%
daysDF = dataDF["Which days of the week do you most often watch this sport?"].value_counts()

dayPercent = daysDF / len(dataDF)
dayPercent *100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Which days of the week do you most often watch this sport?'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
timeDF = editeddataDF["What time of day do you usually watch?"].value_counts()

timePercent = timeDF / len(editeddataDF)
timePercent *100
# Out:
# What time of day do you usually watch?
# Evening      33.333333
# Night        33.333333
# Afternoon    29.629630
# Morning       3.703704
# Name: count, dtype: float64

# %%
whereDF = editeddataDF["Where do you usually watch?"].value_counts()

wherePercent = whereDF / len(editeddataDF)
wherePercent *100
# Out:
# Where do you usually watch?
# At home               77.777778
# Friend's house        11.111111
# School                 3.703704
# At the Krusty krab     3.703704
# At the event           3.703704
# Name: count, dtype: float64

# %%
WhyDF = editeddataDF["Why is that your favorite sport to watch?"].value_counts()

whyPercent = WhyDF / len(editeddataDF)
whyPercent *100
# Out:
# Why is that your favorite sport to watch?
# Most interesting        33.333333
# Grew up watching        29.629630
# Used to play            25.925926
# Family members watch     7.407407
# Idk tbh                  3.703704
# Name: count, dtype: float64

# %%
whyDayDF = editeddataDF["Why do you usually watch on that day?"].value_counts()

whyDayPercent = whyDayDF / len(editeddataDF)
whyDayPercent *100
# Out:
# Why do you usually watch on that day?
# Most games during this day            55.555556
# Most time to watch during this day    33.333333
# Tradition                             11.111111
# Name: count, dtype: float64

# %%
whyPlaceDF = editeddataDF["Why do you watch at that place?"].value_counts()

whyPlacePercent = whyPlaceDF / len(editeddataDF)
whyPlacePercent *100
# Out:
# Why do you watch at that place?
# Spend most of my time there    48.148148
# Relaxing                       33.333333
# More fun                       14.814815
# Because                         3.703704
# Name: count, dtype: float64
